# %% [markdown]
# Task D1: Grade Allocation
# apply a grading system based on the student Average
# - Avg >= 85: Grade A (Score: 10)
# - Avg >= 70: Grade B (Score: 8)
# - Avg >= 50: Grade C (Score: 6)
# - Below 50: No Grade  (Score: 0)
#
# requirement: Use nested conditional logic within numpy

# %% [markdown]
# # 🎓 Task D1: Grade Allocation Using NumPy (Nested Conditional Logic)
#
# ## 🧠 Goal
#
# Assign grades based on student **average marks** using **nested conditional logic in NumPy**.
#
# ### 📌 Grading Rules
#
# * Avg ≥ 85 → **Grade A** (Score: 10) 🏆
# * Avg ≥ 70 → **Grade B** (Score: 8) ⭐
# * Avg ≥ 50 → **Grade C** (Score: 6) 👍
# * Avg < 50 → **No Grade** (Score: 0) ❌
#
# ---
#
# ## ✅ Step 1: Create Average Marks Array
#
# ```python
# import numpy as np
#
# avg = np.array([92, 76, 64, 45, 88, 53])
# ```
#
# 👉 This array stores students’ average scores.
#
# ---
#
# ## ✅ Step 2: Apply Nested Conditional Logic (`np.where`)
#
# We use **nested `np.where()`** to check multiple conditions in order.
#
# ```python
# scores = np.where(avg >= 85, 10,
#          np.where(avg >= 70, 8,
#          np.where(avg >= 50, 6, 0)))
# ```
#
# 👉 NumPy checks conditions **from top to bottom**.
#
# ---
#
# ## ✅ Step 3: (Optional) Assign Grade Labels
#
# ```python
# grades = np.where(avg >= 85, "A",
#          np.where(avg >= 70, "B",
#          np.where(avg >= 50, "C", "No Grade")))
# ```
#
# ---
#
# ## 📊 Output
#
# ```python
# print("Averages:", avg)
# print("Scores:", scores)
# print("Grades:", grades)
# ```
#
# Example output:
#
# ```
# Averages: [92 76 64 45 88 53]
# Scores:   [10  8  6  0 10  6]
# Grades:   ['A' 'B' 'C' 'No Grade' 'A' 'C']
# ```
#
# ---
#
# ## 🚀 Why Use Nested `np.where()`?
#
# Nested `np.where()` lets us apply **multiple conditions** on arrays without loops.
#
# ✨ Fast and efficient
# 📊 Perfect for grading and classification
# 🤖 Common in ML preprocessing
#
# ---
#
# ## 🎯 Viva Line
#
# > Nested `np.where()` applies multiple conditional rules to assign grades efficiently in a vectorized way.

# %%
import numpy as np

# Create an array of student average marks
avg = np.array([92, 76, 64, 45, 88, 53])

# Apply nested conditional logic for grade allocation
# Avg >= 85 → Score 10
# Avg >= 70 → Score 8
# Avg >= 50 → Score 6
# Below 50 → Score 0
scores = np.where(avg >= 85, 10,
         np.where(avg >= 70, 8,
         np.where(avg >= 50, 6, 0)))

# Display results
print("Student averages:", avg)
print("Grade scores:", scores)

# %% [markdown]
# Very Important

# %% [markdown]
# # 🧠 Nested `np.where()` — Layout Guide
#
# ## 📌 Basic `np.where()` Syntax
#
# ```python
# np.where(condition, value_if_true, value_if_false)
# ```
#
# 👉 Meaning:
#
# * If **condition is True** → return `value_if_true`
# * Else → return `value_if_false`
#
# ---
#
# ## 🔥 Nested `np.where()` Layout
#
# Nested means putting another `np.where()` inside the **else part**.
#
# ```python
# np.where(condition1, value1,
#     np.where(condition2, value2,
#         np.where(condition3, value3,
#             default_value)))
# ```
#
# ---
#
# ## 🎯 Logical Flow (Like if–elif–else)
#
# ```
# IF condition1 → value1
# ELSE IF condition2 → value2
# ELSE IF condition3 → value3
# ELSE → default_value
# ```
#
# 👉 Conditions are checked **top to bottom**.
#
# ---
#
# ## ✅ Example: Grade Allocation
#
# ```python
# scores = np.where(avg >= 85, 10,
#           np.where(avg >= 70, 8,
#           np.where(avg >= 50, 6,
#                    0)))
# ```
#
# ---
#
# ## 🧩 Clean Indentation Style
#
# Write nested `np.where()` like stairs for readability:
#
# ```python
# scores = np.where(avg >= 85, 10,
#           np.where(avg >= 70, 8,
#           np.where(avg >= 50, 6,
#                    0)))
# ```
#
# 👉 Proper indentation makes the logic easy to understand.
#
# ---
#
# ## ⭐ Golden Rule
#
# Nested `np.where()` works like:
#
# ```
# if → elif → elif → else
# ```
#
# ---
#
# ## 💡 Memory Trick
#
# Think of nested `np.where()` like layers:
#
# ```
# WHERE(
#   IF,
#   ELSE → WHERE(
#            IF,
#            ELSE → WHERE(...)
#          )
# )
# ```
#
# It’s like stacking conditions step by step.
