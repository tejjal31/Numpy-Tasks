# %%
import numpy as np

# -----------------------------------
# Task 1.1: Create cost price array
# -----------------------------------
arr = np.array([1500, 3000, 5000])

# -----------------------------------
# Task 1.2: Create daily sales matrix
# Rows: Headphones, Smartphones, Speakers
# Columns: Monday to Thursday
# -----------------------------------
arr2 = np.array([
    [10, 15, 8, 12],
    [5, 7, 4, 6],
    [2, 3, 2, 4]
])

# -----------------------------------
# Task 1.3: Print shape & dimension
# -----------------------------------
print("Cost price shape:", arr.shape)
print("Cost price dimension:", arr.ndim)

print("Daily sales shape:", arr2.shape)
print("Daily sales dimension:", arr2.ndim)
# Out:
# Cost price shape: (3,)
# Cost price dimension: 1
# Daily sales shape: (3, 4)
# Daily sales dimension: 2
